# %% [markdown]
# ### India Census 2011 dataset

# %%
import pandas as pd
# %matplotlib inline 
import matplotlib.pyplot as plt

# importing the dataset using the pandas
df = pd.read_csv("india_census_2011.csv")

# %%
df.shape
# Out:
# (640, 25)

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
df.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %%
# we can hide the index of the dataframe
df.style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %%
df.style.set_caption("India Census 2011 Dataset")
# Out:
# <style  type="text/css" >
# ...

# %%
# Heat map for checking highly correlated columns
import seaborn as sb
plt.rcParams['figure.figsize'] = 8,7
sb.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# using below syntax we can access any specific column of the dataset
df['District_name']
# Out:
# 0                        Kupwara
# 1                         Badgam
# 2                    Leh(Ladakh)
# 3                         Kargil
# 4                          Punch
#                  ...
# 635                         Mahe
# 636                     Karaikal
# 637                     Nicobars
# 638    North  AND Middle Andaman
# 639                South Andaman
# Name: District_name, Length: 640, dtype: object

# %%
# isin() methode basically finds the required result is present or not
is_present = df['District_name'].isin(['New Delhi', 'Patna', 'Varanasi'])

df[is_present]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 196            197  UTTAR PRADESH      Varanasi     3676841  1921857  1754984
# 229            230          BIHAR         Patna     5838465  3078512  2759953
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 196   2403903  1220708        921234          299474  ...        7696   3309
# 229   3459679  1881886       1436411          445475  ...       12551   4803
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 196       1146   1898               447926            351391
# 229       1062   2151               698351            463361
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# - Calculating state-wise
#     - total popluation
#     - total popluation with different religions

# %%
# so inorder to get data in group wise like state as given in problem
# we will use groupby method

df.groupby('State_name').Population.sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
# printing population count state wise in descending order


df.groupby('State_name').Population.sum().sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 Hindus   Muslims  ...  Buddhists    Jains
# State_name                                        ...
# ANDAMAN AND NICOBAR ISLANDS     264296     32413  ...        338       31
# ANDHRA PRADESH                74824149   8082412  ...      36692    53849
# ARUNACHAL PRADESH               401876     27045  ...     162815      771
# ASSAM                         19180759  10679345  ...      54993    25949
# BIHAR                         86078686  17557809  ...      25453    18914
# CHANDIGARH                      852574     51447  ...       1160     1960
# CHHATTISGARH                  23819789    514998  ...      70467    61510
# DADRA AND NAGAR HAVELI          322857     12922  ...        634     1186
# ...

# %%
df.columns

# %%
df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum().sort_values(ascending = False, by = 'Christians')
# Out:
# <ipython-input-11-5e8f40151dc5>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum().sort_values(ascending = False, by = 'Christians')
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# KERALA                        18282492   8873472     6141269      3814
# TAMIL NADU                    63188168   4229479     4418331     14601
# MEGHALAYA                       342078    130399     2213027      3045
# NAGALAND                        173054     48963     1739651      1890
# JHARKHAND                     22376051   4793994     1418608     71422
# MANIPUR                        1181876    239836     1179043      1527
# ASSAM                         19180759  10679345     1165867     20672
# ORISSA                        39300341    911670     1161708     21991
# ...

# %% [markdown]
# - Calculating Male workers in Bihar

# %%
male_worker = df[df.State_name == 'UTTAR PRADESH']['Male_Workers'].sum()
female_worker = df[df.State_name == 'UTTAR PRADESH']['Female_Workers'].sum()

print("Male Workers in UTTAR PRADESH: ", male_worker)
print("Female Workers in UTTAR PRADESH: ", female_worker)
# Out:
# Male Workers in UTTAR PRADESH:  49846762
# Female Workers in UTTAR PRADESH:  15967953

# %%
# setting column as index
df.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %%
# if you want to save the change to dataframe 
# //then save it back to df = df.add_suffix('right_main_addhoga')
df.add_suffix('right_main_addhoga')

# %%
df.add_prefix('left_main_addhoga')
# Out:
#      left_main_addhogaDistrict_code  left_main_addhogaState_name  \
# 0                                 1            JAMMU AND KASHMIR
# 1                                 2            JAMMU AND KASHMIR
# 2                                 3            JAMMU AND KASHMIR
# 3                                 4            JAMMU AND KASHMIR
# 4                                 5            JAMMU AND KASHMIR
# ..                              ...                          ...
# 635                             636                  PONDICHERRY
# 636                             637                  PONDICHERRY
# 637                             638  ANDAMAN AND NICOBAR ISLANDS
# 638                             639  ANDAMAN AND NICOBAR ISLANDS
# 639                             640  ANDAMAN AND NICOBAR ISLANDS
#
#     left_main_addhogaDistrict_name  left_main_addhogaPopulation  \
# 0                          Kupwara                       870354
# ...

# %%
viz=df[['Literate','Male_Workers','Female_Workers','Cultivator_Workers']]
viz.hist(color='lightseagreen')
plt.show()
plt.rcParams['figure.figsize'] = 13,9
